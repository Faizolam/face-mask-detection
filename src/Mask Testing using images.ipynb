# %%
# import the necessary packages
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import cv2
import os

# %%
# load our serialized face detector model from disk
prototxtPath=os.path.sep.join([r'D:\Face mask detector\dataset\face_detector','deploy.prototxt'])
weightsPath=os.path.sep.join([r'D:\Face mask detector\dataset\face_detector','res10_300x300_ssd_iter_140000.caffemodel'])

# %%
# prototxtPath

# %%
# weightsPath

# %%
net=cv2.dnn.readNet(prototxtPath,weightsPath)

# %%
# net

# %%
model=load_model(r'D:\Face mask detector\dataset\face_mobilenet_v2.model')

# %%
image=cv2.imread(r'D:\Face mask detector\dataset\example\example_05.png')

# %%
image
# Out:
# array([[[ 98, 127, 163],
#         [ 98, 127, 163],
#         [ 98, 127, 163],
#         ...,
#         [143, 166, 194],
#         [143, 166, 194],
#         [143, 166, 194]],
#
#        [[ 92, 117, 157],
#         [ 92, 117, 157],
#         [ 98, 127, 163],
#         ...,
#         [143, 166, 194],
#         [143, 166, 194],
#         [143, 166, 194]],
#
#        [[ 98, 127, 163],
#         [ 92, 117, 157],
#         [ 98, 127, 163],
#         ...,
#         [143, 166, 194],
#         [143, 166, 194],
#         [143, 166, 194]],
#
#        ...,
#
#        [[128, 155, 190],
#         [121, 148, 183],
#         [ 98, 127, 163],
#         ...,
#         [194, 175, 158],
#         [194, 175, 158],
#         [190, 172, 156]],
#
#        [[121, 148, 183],
#         [121, 148, 183],
#         [128, 155, 190],
#         ...,
#         [194, 175, 158],
#         [194, 175, 158],
#         [190, 172, 156]],
#
#        [[ 47,  76, 123],
#         [ 55,  90, 137],
#         [ 84, 110, 151],
#         ...,
#         [190, 172, 156],
#         [187, 169, 154],
#         [190, 172, 156]]], dtype=uint8)

# %%
image.shape
# Out:
# (600, 600, 3)

# %%
(h,w)=image.shape[:2]

# %%
(h,w)
# Out:
# (600, 600)

# %%
# construct a blob from the image
blob=cv2.dnn.blobFromImage(image,1.0,(300,300),(104.0,177.0,123.0))

# %%
blob
# Out:
# array([[[[  -9.,   -7.,   -9., ...,   39.,   39.,   39.],
#          [  -9.,   -6.,   -7., ...,   40.,   39.,   39.],
#          [  -6.,   -7.,   -9., ...,   38.,   39.,   39.],
#          ...,
#          [ -42.,  -56.,   18., ...,   81.,   82.,   85.],
#          [   8.,  -28.,   20., ...,   85.,   86.,   86.],
#          [ -18.,    7.,   16., ...,   89.,   87.,   86.]],
#
#         [[ -55.,  -52.,  -55., ...,  -11.,  -11.,  -11.],
#          [ -55.,  -50.,  -52., ...,  -10.,  -11.,  -11.],
#          [ -50.,  -52.,  -55., ...,  -12.,  -11.,  -11.],
#          ...,
#          [ -98., -113.,  -28., ...,  -10.,   -9.,   -6.],
#          [ -39.,  -76.,  -26., ...,   -6.,   -6.,   -5.],
#          [ -61.,  -39.,  -30., ...,   -3.,   -4.,   -5.]],
#
#         [[  37.,   39.,   37., ...,   71.,   71.,   71.],
#          [  37.,   40.,   39., ...,   71.,   71.,   71.],
#          [  40.,   39.,   37., ...,   71.,   67.,   71.],
#          ...,
#          [ -18.,  -40.,   61., ...,   29.,   30.,   32.],
#          [  52.,   11.,   63., ...,   33.,   33.,   33.],
#          [  34.,   52.,   59., ...,   35.,   34.,   33.]]]], dtype=float32)

# %%
blob.shape
# Out:
# (1, 3, 300, 300)

# %%
# pass the blob through the network and obtain the face detection
net.setInput(blob)
detections=net.forward()

# %%
detections
# Out:
# array([[[[ 0.00000000e+00,  1.00000000e+00,  9.89378273e-01,
#            5.76706469e-01,  2.20713884e-01,  7.32671440e-01,
#            3.63932043e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.84387636e-01,
#            9.22202244e-02,  3.33555907e-01,  2.57166564e-01,
#            4.88085836e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.75802600e-01,
#            8.15442145e-01,  2.75532961e-01,  9.92336690e-01,
#            4.46491063e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.47812617e-01,
#            3.32406849e-01,  3.89148355e-01,  4.83362347e-01,
#            5.44419885e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  1.26217321e-01,
#            2.08635032e-02,  1.25927866e-01,  9.85216618e-01,
#            8.70008409e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  1.23381503e-01,
#            4.15460300e+00,  4.00493193e+00,  4.84318829e+00,
#            4.97861433e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  1.22972429e-01,
#            4.01592731e+00,  1.29618913e-01,  4.97623444e+00,
#            8.73460293e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  1.21063516e-01,
#            4.35325474e-01,  1.55189201e-01,  4.99800712e-01,
#            2.11804703e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  1.16631247e-01,
#            1.57196015e-01,  4.00853014e+00,  8.45193982e-01,
#            4.98468637e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  1.08593993e-01,
#            3.54821742e-01,  4.86669928e-01,  4.72065449e-01,
#            5.91079116e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.93783250e-02,
#            2.03569078e+00,  1.31396174e-01,  2.95733786e+00,
#            8.69493008e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.85201076e-02,
#            5.69852702e-02,  5.22252560e-01,  1.37084663e-01,
#            6.20401382e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.83118564e-02,
#            4.39869016e-01,  1.62144899e-01,  4.76517946e-01,
#            1.98832929e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.79914442e-02,
#            3.03742647e+00,  1.30624533e-01,  3.95915031e+00,
#            8.70831847e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.77860019e-02,
#            1.04086053e+00,  1.30191445e-01,  1.96019328e+00,
#            8.68565559e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.73451287e-02,
#            5.75119197e-01,  7.73523211e-01,  7.25237548e-01,
#            1.00955892e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  9.43481773e-02,
#            4.26937252e-01,  1.63008749e-01,  4.79046255e-01,
#            2.28311449e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.24498588e-02,
#            4.13445902e+00,  3.07560420e+00,  4.85566378e+00,
#            3.89922452e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  9.08711106e-02,
#            4.51449215e-01,  1.54076472e-01,  5.20802677e-01,
#            2.36528322e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.04526338e-02,
#            3.10950726e-01,  5.10412753e-01,  3.72556478e-01,
#            5.79662263e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  9.00933072e-02,
#            4.12510300e+00,  1.08495104e+00,  4.85915852e+00,
#            1.90011632e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  8.99922624e-02,
#            2.64981508e-01,  4.95468408e-01,  3.37853193e-01,
#            5.81579149e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  8.97230357e-02,
#            4.12702417e+00,  2.08318591e+00,  4.85347986e+00,
#            2.90802646e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  8.96133482e-02,
#            1.13905144e+00,  4.06954575e+00,  1.87191367e+00,
#            4.89611053e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  8.94739181e-02,
#            4.17148203e-01,  1.68875068e-01,  4.49370891e-01,
#            2.07106531e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  8.92593414e-02,
#            3.11736321e+00,  4.05537939e+00,  3.87896991e+00,
#            4.90171862e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  8.85428712e-02,
#            2.55890161e-01,  3.83257329e-01,  3.60512942e-01,
#            5.61163962e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  8.79629031e-02,
#            4.24251318e-01,  1.80552036e-01,  5.10510266e-01,
#            2.60738075e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  8
-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.98129663e-02,
#            9.39531997e-03,  6.21224225e-01,  6.73368126e-02,
#            7.72460520e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.97876939e-02,
#            5.93970001e-01,  8.65116775e-01,  6.63948834e-01,
#            1.00591230e+00],
#          [ 0.00000000e+00,  1.00000000e+00,  7.96335489e-02,
#            2.52370864e-01,  4.09233689e-01,  3.17904443e-01,
#            5.33271492e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.89224207e-02,
#            4.50118542e-01,  1.29765585e-01,  5.85312843e-01,
#            2.55179048e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.88931400e-02,
#            4.01840329e-01,  1.63358763e-01,  4.30288970e-01,
#            1.94926843e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.88738430e-02,
#            4.08035457e-01,  1.54282928e-01,  4.41741943e-01,
#            1.91527814e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.88334757e-02,
#            3.81590366e-01,  9.53382328e-02,  5.10305047e-01,
#            2.33435899e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.84248561e-02,
#            2.78931931e-02,  4.24250841e-01,  9.68958661e-02,
#            5.57555735e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.83283412e-02,
#            4.09215361e-01,  3.01961064e-01,  5.16537905e-01,
#            3.67606163e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.82530606e-02,
#            4.23547715e-01,  1.44379273e-01,  4.61535007e-01,
#            1.78507730e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.81815499e-02,
#            1.01448274e+00, -6.35473132e-02,  1.84971619e+00,
#            4.48692441e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.79716447e-02,
#            4.37808126e-01,  2.56842554e-01,  5.41832507e-01,
#            3.48930657e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.79332593e-02,
#            3.68177295e-01,  1.96785793e-01,  4.08960283e-01,
#            2.52506435e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.78661445e-02,
#            3.29507351e-01,  4.84786451e-01,  4.18045998e-01,
#            5.56125820e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.77717382e-02,
#            3.86232615e-01,  2.03824818e-01,  4.39196706e-01,
#            2.61173546e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.74967670e-02,
#            2.08562508e-01,  4.67707396e-01,  3.20821106e-01,
#            6.19804740e-01],
#          [ 0.00000000e+00,  1.00000000e+00,  7.74750933e-02,
#            3.05659682e-01,  5.36267877e-01,  3.83343786e-01,
#            5.98477364e-01]]]], dtype=float32)

# %%
#loop over the detections
for i in range(0,detections.shape[2]):
    confidence=detections[0,0,i,2]
    
    
    if confidence>0.5:
        #we need the X,Y coordinates
        box=detections[0,0,i,3:7]*np.array([w,h,w,h])
        (startX,startY,endX,endY)=box.astype('int')
        
        #ensure the bounding boxes fall within the dimensions of the frame
        (startX,startY)=(max(0,startX),max(0,startY))
        (endX,endY)=(min(w-1,endX), min(h-1,endY))
        
        #extract the face ROI, convert it from BGR to RGB channel, resize it to 224,224 and preprocess it
        face=image[startY:endY, startX:endX]
        face=cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
        face=cv2.resize(face,(224,224))
        face=img_to_array(face)
        face=preprocess_input(face)
        face=np.expand_dims(face,axis=0)
        
        # pass the face through the model to determine if the face has a mask or not
        (mask,withoutMask)=model.predict(face)[0]
        
        #determine the class label and color we will use to draw the bounding box and text
        label='Mask' if mask>withoutMask else 'No Mask'
        color=(0,255,0) if label=='Mask' else (0,0,255)
        
        #include the probability in the label
        label="{}: {:.2f}%".format(label,max(mask,withoutMask)*100)
        
        #display the label and bounding boxes
        cv2.putText(image,label,(startX,startY-10),cv2.FONT_HERSHEY_SIMPLEX,0.45,color,2)
        cv2.rectangle(image,(startX,startY),(endX,endY),color,2)
        
        
        
cv2.imshow("OutPut",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
